# %%
#import warnings
from chefboost import Chefboost as chef
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import f1_score,confusion_matrix,roc_auc_score
from sklearn.model_selection import train_test_split,StratifiedKFold

# %%
all_merged=pd.read_csv("C:/Users/Melaku/Desktop/Thesis_02/csv/final02.csv",sep=',',index_col='hhid')

# %%
all_merged.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'main_occupation', 'marital_status',
#        'Q3098n', 'Q3099n', 'Q30910n', 'Q30911n', 'food_secured'],
#       dtype='object')

# %%
all_merged.shape
# Out:
# (13626, 25)

# %%
all_merged.astype(int)
# Out:
#            hh_members  sex  hh_education  residence  age  altitude  Q401  \
# hhid
# DT0100002           1    1             0          0    1         2     1
# DT0100005           1    1             1          0    1         2     1
# DT0100006           0    1             3          0    1         2     1
# DT0100007           0    1             3          0    1         2     1
# DT0100011           0    1             3          0    0         2     1
# ...               ...  ...           ...        ...  ...       ...   ...
# DT1301282           1    0             0          1    1         2     2
# DT1301283           1    1             1          1    1         2     2
# DT1301284           1    1             3          1    1         2     2
# DT1301285           1    1             1          1    1         2     2
# DT1301286           1    1             0          1    1         2     2
#
#            Q304  Q306  Q307  ...  Q5233  Q5234  Q524  main_occupation  \
# hhid                         ...
# DT0100002     1     3     2  ...      2      2     1                2
# DT0100005     1     1     3  ...      2      2     1                3
# DT0100006     1     1     3  ...      2      2     1                4
# DT0100007     1     1     3  ...      2      2     1                4
# DT0100011     1     1     3  ...      2      2     1                2
# ...         ...   ...   ...  ...    ...    ...   ...              ...
# DT1301282     1     3     2  ...      2      2     1                2
# DT1301283     1     4     2  ...      2      2     1                2
# DT1301284     1     3     2  ...      2      2     1                2
# DT1301285     1     3     2  ...      2      2     2                2
# DT1301286     1     3     2  ...      2      2     1                2
#
#            marital_status  Q3098n  Q3099n  Q30910n  Q30911n  food_secured
# hhid
# DT0100002               1       1       1        1        1             0
# DT0100005               1       0       0        0        0             0
# DT0100006               1       0       0        0        0             1
# DT0100007               1       0       0        1        0             0
# DT0100011               2       0       0        0        0             0
# ...                   ...     ...     ...      ...      ...           ...
# DT1301282               4       1       0        1        1             1
# DT1301283               1       1       0        1        1             0
# DT1301284               1       1       1        1        1             0
# DT1301285               1       1       2        1        1             1
# DT1301286               1       1       0        1        0             0
#
# [13626 rows x 25 columns]

# %%
all_merged.sort_index()
# Out:
#            hh_members  sex  hh_education  residence  age  altitude  Q401  \
# hhid
# DT0100002           1    1             0          0    1         2     1
# DT0100005           1    1             1          0    1         2     1
# DT0100006           0    1             3          0    1         2     1
# DT0100007           0    1             3          0    1         2     1
# DT0100011           0    1             3          0    0         2     1
# ...               ...  ...           ...        ...  ...       ...   ...
# DT1301282           1    0             0          1    1         2     2
# DT1301283           1    1             1          1    1         2     2
# DT1301284           1    1             3          1    1         2     2
# DT1301285           1    1             1          1    1         2     2
# DT1301286           1    1             0          1    1         2     2
#
#            Q304  Q306  Q307  ...  Q5233  Q5234  Q524  main_occupation  \
# hhid                         ...
# DT0100002     1     3     2  ...      2      2     1                2
# DT0100005     1     1     3  ...      2      2     1                3
# DT0100006     1     1     3  ...      2      2     1                4
# DT0100007     1     1     3  ...      2      2     1                4
# DT0100011     1     1     3  ...      2      2     1                2
# ...         ...   ...   ...  ...    ...    ...   ...              ...
# DT1301282     1     3     2  ...      2      2     1                2
# DT1301283     1     4     2  ...      2      2     1                2
# DT1301284     1     3     2  ...      2      2     1                2
# DT1301285     1     3     2  ...      2      2     2                2
# DT1301286     1     3     2  ...      2      2     1                2
#
#            marital_status  Q3098n  Q3099n  Q30910n  Q30911n  food_secured
# hhid
# DT0100002               1       1       1        1        1             0
# DT0100005               1       0       0        0        0             0
# DT0100006               1       0       0        0        0             1
# DT0100007               1       0       0        1        0             0
# DT0100011               2       0       0        0        0             0
# ...                   ...     ...     ...      ...      ...           ...
# DT1301282               4       1       0        1        1             1
# DT1301283               1       1       0        1        1             0
# DT1301284               1       1       1        1        1             0
# DT1301285               1       1       2        1        1             1
# DT1301286               1       1       0        1        0             0
#
# [13626 rows x 25 columns]

# %%
#all_merged.rename(columns={"food_secured":"Decision"},inplace=True)

# %%
print(type(all_merged))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
all_merged.shape
# Out:
# (13626, 25)

# %%
all_merged.isnull().sum().sum()
# Out:
# 0

# %%
all_merged.shape
# Out:
# (13626, 25)

# %%
all_merged.duplicated().sum()
# Out:
# 1471

# %%
#all_merged.drop_duplicates(inplace=True)

# %%
all_merged['hh_members'].value_counts(0)
# Out:
# 0    7505
# 1    5744
# 2     377
# Name: hh_members, dtype: int64

# %%
all_merged.shape
# Out:
# (13626, 25)

# %%
all_merged.rename(columns={"food_secured": "Food_secured"},inplace=True)

# %%
#all_merged['target'].replace({2:0},inplace=True)
all_merged['Food_secured'].replace({0:"No",1:"Yes"},inplace=True)

# %%
#all_merged['hh_members'].replace({0:"1-4",1:"5-8",2:">=9"},inplace=True)
all_merged['hh_members'].replace({0:"1-4",1:"5-8",2:">=9"},inplace=True)

# %%
all_merged['sex'].replace({0:"Female",1:"Male"},inplace=True)

# %%
all_merged['hh_education'].value_counts()
# Out:
# 0    7017
# 1    3218
# 2    1541
# 3    1252
# 4     598
# Name: hh_education, dtype: int64

# %%
all_merged['hh_education'].replace({0:"Illitrate",1:'Elementary',2:"Secondary",3:"Teritary",4:"Teritary"},inplace=True)

# %%
all_merged['main_occupation'].value_counts()
# Out:
# 2    10689
# 4     1225
# 3     1143
# 1      395
# 0      174
# Name: main_occupation, dtype: int64

# %%
all_merged['main_occupation'].replace({0:"Other",1:"Student",2:"Farmer",3:"Self_employmnet",4:"Employee"},inplace=True)

# %%
all_merged['marital_status'].value_counts()
# Out:
# 1    9338
# 4    1799
# 3    1315
# 2     689
# 0     485
# Name: marital_status, dtype: int64

# %%
all_merged['marital_status'].replace({0:"Separated",1:"Married",2:"Single",3:"Divorced",4:"Widowed"},inplace=True)

# %%
all_merged['age'].value_counts()
# Out:
# 1    6268
# 0    5076
# 2    2282
# Name: age, dtype: int64

# %%
all_merged['age'].replace({0:"15-38",1:"39-60",2:"61-84"},inplace=True)

# %%
all_merged['altitude'].value_counts()
# Out:
# 2    10114
# 1     2082
# 0     1430
# Name: altitude, dtype: int64

# %%
all_merged['altitude'].replace({0:"Kolla",1:"Woina_dega",2:"Dega"},inplace=True)

# %%
all_merged['Q401'].value_counts()
# Out:
# 2    6995
# 1    6631
# Name: Q401, dtype: int64

# %%
all_merged['Q401'].replace({1:"Clean",2:"Unclean"},inplace=True)

# %%
all_merged['Q3098n'].value_counts()
# Out:
# 1    8092
# 0    5534
# Name: Q3098n, dtype: int64

# %%
all_merged['Q3098n'].replace({0:"none",1:"1-3"},inplace=True)

# %%
all_merged['Q30910n'].value_counts()
# Out:
# 0    9084
# 1    4542
# Name: Q30910n, dtype: int64

# %%
all_merged['Q30910n'].replace({0:"None",1:"1-5"},inplace=True)

# %%
all_merged['Q30911n'].value_counts()
# Out:
# 1    7351
# 0    6275
# Name: Q30911n, dtype: int64

# %%
all_merged['Q30911n'].replace({0:"none",1:"1-3"},inplace=True)

# %%
all_merged['Q306'].value_counts()
# Out:
# 3    7894
# 1    4283
# 4    1364
# 2      85
# Name: Q306, dtype: int64

# %%
all_merged['Q306'].replace({1:"Electricity",2:"Kerosene",3:"Battry",4:"Wood/other"},inplace=True)

# %%
all_merged['Q307'].value_counts()
# Out:
# 2    9146
# 3    3298
# 1    1021
# 4     161
# Name: Q307, dtype: int64

# %%
all_merged['Q307'].replace({1:"Wood",2:"Muck",3:"Charcoal",4:"Electricity"},inplace=True)

# %%
all_merged['Q308m'].value_counts()
# Out:
# 0    10432
# 1     3194
# Name: Q308m, dtype: int64

# %%
all_merged['Q308m'].replace({0:"No",1:"Yes"},inplace=True)

# %%
all_merged['Qsou_inform'].value_counts()
# Out:
# 0    8872
# 1    2991
# 2    1405
# 3     358
# Name: Qsou_inform, dtype: int64

# %%
all_merged['Qsou_inform'].replace({0:"Never",1:"One_media",2:"Two_media",3:"Three_media"},inplace=True)

# %%
all_merged['Q504'].value_counts()
# Out:
# 2    6415
# 1    5292
# 4     856
# 5     743
# 3     320
# Name: Q504, dtype: int64

# %%
all_merged['Q504'].replace({1:"Own_production",2:"Purchase",3:"Support",4:"Land_Rent",5:"Other"},inplace=True)

# %%
all_merged['Q524'].replace({2:"No",1:"Yes"},inplace=True)

# %%
all_merged['Q5231'].replace({1:"Yes",2:"No"},inplace=True)

# %%
all_merged['Q5232'].replace({1:"Yes",2:"No"},inplace=True)

# %%
all_merged['Q5233'].replace({1:"Yes",2:"No"},inplace=True)

# %%
all_merged['Q5234'].replace({1:"Yes",2:"No"},inplace=True)

# %%
all_merged['residence'].replace({1:"Rural",0:"Urban"},inplace=True)

# %%
all_merged['Q304'].value_counts()
# Out:
# 1    11225
# 2     1849
# 3      552
# Name: Q304, dtype: int64

# %%
all_merged['Q304'].replace({1:"Rent",2:"Private",3:"Government"},inplace=True)

# %%
all_merged.dtypes
# Out:
# hh_members         object
# sex                object
# hh_education       object
# residence          object
# age                object
# altitude           object
# Q401               object
# Q304               object
# Q306               object
# Q307               object
# Q308m              object
# Qsou_inform        object
# Q504               object
# Q5231              object
# Q5232              object
# Q5233              object
# Q5234              object
# Q524               object
# main_occupation    object
# marital_status     object
# Q3098n             object
# Q3099n              int64
# Q30910n            object
# Q30911n            object
# Food_secured       object
# dtype: object

# %%
all_merged
# Out:
#           hh_members     sex hh_education residence    age altitude     Q401  \
# hhid
# DT0100002        5-8    Male    Illitrate     Urban  39-60     Dega    Clean
# DT0100005        5-8    Male   Elementary     Urban  39-60     Dega    Clean
# DT0100006        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100007        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100011        1-4    Male     Teritary     Urban  15-38     Dega    Clean
# ...              ...     ...          ...       ...    ...      ...      ...
# DT1301282        5-8  Female    Illitrate     Rural  39-60     Dega  Unclean
# DT1301283        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301284        5-8    Male     Teritary     Rural  39-60     Dega  Unclean
# DT1301285        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301286        5-8    Male    Illitrate     Rural  39-60     Dega  Unclean
#
#            Q304         Q306      Q307  ... Q5233 Q5234 Q524  main_occupation  \
# hhid                                    ...
# DT0100002  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT0100005  Rent  Electricity  Charcoal  ...    No    No  Yes  Self_employmnet
# DT0100006  Rent  Electricity  Charcoal  ...    No    No  Yes         Employee
# DT0100007  Rent  Electricity  Charcoal  ...    No    No  Yes         Employee
# DT0100011  Rent  Electricity  Charcoal  ...    No    No  Yes           Farmer
# ...         ...          ...       ...  ...   ...   ...  ...              ...
# DT1301282  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT1301283  Rent   Wood/other      Muck  ...    No    No  Yes           Farmer
# DT1301284  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT1301285  Rent       Battry      Muck  ...    No    No   No           Farmer
# DT1301286  Rent       Battry      Muck  ...    No    No  Yes           Farmer
#
#           marital_status Q3098n Q3099n Q30910n Q30911n Food_secured
# hhid
# DT0100002        Married    1-3      1     1-5     1-3           No
# DT0100005        Married   none      0    None    none           No
# DT0100006        Married   none      0    None    none          Yes
# DT0100007        Married   none      0     1-5    none           No
# DT0100011         Single   none      0    None    none           No
# ...                  ...    ...    ...     ...     ...          ...
# DT1301282        Widowed    1-3      0     1-5     1-3          Yes
# DT1301283        Married    1-3      0     1-5     1-3           No
# DT1301284        Married    1-3      1     1-5     1-3           No
# DT1301285        Married    1-3      2     1-5     1-3          Yes
# DT1301286        Married    1-3      0     1-5    none           No
#
# [13626 rows x 25 columns]

# %%
from chefboost import Chefboost as chef

# %%
all_merged.shape
# Out:
# (13626, 25)

# %%
all_merged
# Out:
#           hh_members     sex hh_education residence    age altitude     Q401  \
# hhid
# DT0100002        5-8    Male    Illitrate     Urban  39-60     Dega    Clean
# DT0100005        5-8    Male   Elementary     Urban  39-60     Dega    Clean
# DT0100006        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100007        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100011        1-4    Male     Teritary     Urban  15-38     Dega    Clean
# ...              ...     ...          ...       ...    ...      ...      ...
# DT1301282        5-8  Female    Illitrate     Rural  39-60     Dega  Unclean
# DT1301283        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301284        5-8    Male     Teritary     Rural  39-60     Dega  Unclean
# DT1301285        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301286        5-8    Male    Illitrate     Rural  39-60     Dega  Unclean
#
#            Q304         Q306      Q307  ... Q5233 Q5234 Q524  main_occupation  \
# hhid                                    ...
# DT0100002  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT0100005  Rent  Electricity  Charcoal  ...    No    No  Yes  Self_employmnet
# DT0100006  Rent  Electricity  Charcoal  ...    No    No  Yes         Employee
# DT0100007  Rent  Electricity  Charcoal  ...    No    No  Yes         Employee
# DT0100011  Rent  Electricity  Charcoal  ...    No    No  Yes           Farmer
# ...         ...          ...       ...  ...   ...   ...  ...              ...
# DT1301282  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT1301283  Rent   Wood/other      Muck  ...    No    No  Yes           Farmer
# DT1301284  Rent       Battry      Muck  ...    No    No  Yes           Farmer
# DT1301285  Rent       Battry      Muck  ...    No    No   No           Farmer
# DT1301286  Rent       Battry      Muck  ...    No    No  Yes           Farmer
#
#           marital_status Q3098n Q3099n Q30910n Q30911n Food_secured
# hhid
# DT0100002        Married    1-3      1     1-5     1-3           No
# DT0100005        Married   none      0    None    none           No
# DT0100006        Married   none      0    None    none          Yes
# DT0100007        Married   none      0     1-5    none           No
# DT0100011         Single   none      0    None    none           No
# ...                  ...    ...    ...     ...     ...          ...
# DT1301282        Widowed    1-3      0     1-5     1-3          Yes
# DT1301283        Married    1-3      0     1-5     1-3           No
# DT1301284        Married    1-3      1     1-5     1-3           No
# DT1301285        Married    1-3      2     1-5     1-3          Yes
# DT1301286        Married    1-3      0     1-5    none           No
#
# [13626 rows x 25 columns]

# %%
all_merged.rename(columns={'Food_secured':'Decision'},inplace=True)

# %%
all_merged.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'main_occupation', 'marital_status',
#        'Q3098n', 'Q3099n', 'Q30910n', 'Q30911n', 'Decision'],
#       dtype='object')

# %%
relevant=['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
       'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
       'Q5232', 'Q5233', 'Q5234', 'Q524','Decision']

# %%
all_merged=all_merged[relevant]

# %%
all_merged.shape
# Out:
# (13626, 19)

# %%
all_merged.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'Decision'],
#       dtype='object')

# %%
len(all_merged)
# Out:
# 13626

# %%
all_merged
# Out:
#           hh_members     sex hh_education residence    age altitude     Q401  \
# hhid
# DT0100002        5-8    Male    Illitrate     Urban  39-60     Dega    Clean
# DT0100005        5-8    Male   Elementary     Urban  39-60     Dega    Clean
# DT0100006        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100007        1-4    Male     Teritary     Urban  39-60     Dega    Clean
# DT0100011        1-4    Male     Teritary     Urban  15-38     Dega    Clean
# ...              ...     ...          ...       ...    ...      ...      ...
# DT1301282        5-8  Female    Illitrate     Rural  39-60     Dega  Unclean
# DT1301283        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301284        5-8    Male     Teritary     Rural  39-60     Dega  Unclean
# DT1301285        5-8    Male   Elementary     Rural  39-60     Dega  Unclean
# DT1301286        5-8    Male    Illitrate     Rural  39-60     Dega  Unclean
#
#            Q304         Q306      Q307 Q308m  Qsou_inform            Q504  \
# hhid
# DT0100002  Rent       Battry      Muck    No        Never       Land_Rent
# DT0100005  Rent  Electricity  Charcoal   Yes    One_media        Purchase
# DT0100006  Rent  Electricity  Charcoal   Yes  Three_media        Purchase
# DT0100007  Rent  Electricity  Charcoal   Yes  Three_media        Purchase
# DT0100011  Rent  Electricity  Charcoal    No    Two_media        Purchase
# ...         ...          ...       ...   ...          ...             ...
# DT1301282  Rent       Battry      Muck    No        Never  Own_production
# DT1301283  Rent   Wood/other      Muck   Yes    One_media        Purchase
# DT1301284  Rent       Battry      Muck   Yes    One_media  Own_production
# DT1301285  Rent       Battry      Muck    No    One_media  Own_production
# DT1301286  Rent       Battry      Muck    No        Never        Purchase
#
#           Q5231 Q5232 Q5233 Q5234 Q524 Decision
# hhid
# DT0100002   Yes    No    No    No  Yes       No
# DT0100005   Yes    No    No    No  Yes       No
# DT0100006    No    No    No    No  Yes      Yes
# DT0100007    No    No    No    No  Yes       No
# DT0100011   Yes    No    No    No  Yes       No
# ...         ...   ...   ...   ...  ...      ...
# DT1301282    No    No    No    No  Yes      Yes
# DT1301283    No    No    No    No  Yes       No
# DT1301284   Yes    No    No    No  Yes       No
# DT1301285    No    No    No    No   No      Yes
# DT1301286    No   Yes    No    No  Yes       No
#
# [13626 rows x 19 columns]

# %%
all_merged.shape
# Out:
# (13626, 19)

# %%
#Here again we identify both independet and depedent variables in to x and y
x=all_merged.drop(['Decision'],axis=1)
y=all_merged['Decision']

# %%
#Split the dataset into train and test set 
x_train,x_test,y_train,y_test =train_test_split(x,y, test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape)#show shape of X_train and Y_train
# Out:
# (10900, 18) (2726, 18)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (10900,) (2726,)

# %%
all_merged.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'Decision'],
#       dtype='object')

# %%
all_merged.shape
# Out:
# (13626, 19)

# %%
train=x_train[['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
       'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
       'Q5232', 'Q5233', 'Q5234', 'Q524']]

# %%
len(train)
# Out:
# 10900

# %%
test=x_test[['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
       'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
       'Q5232', 'Q5233', 'Q5234', 'Q524']]

# %%
train
# Out:
#           hh_members     sex hh_education residence    age    altitude  \
# hhid
# DT0101175        1-4    Male   Elementary     Urban  61-84        Dega
# DT0800529        >=9    Male   Elementary     Rural  39-60  Woina_dega
# DT0801695        1-4    Male    Illitrate     Rural  15-38       Kolla
# DT0101087        1-4  Female    Illitrate     Urban  61-84        Dega
# DT0800565        1-4    Male    Secondary     Rural  15-38       Kolla
# ...              ...     ...          ...       ...    ...         ...
# DT1300742        1-4  Female    Illitrate     Rural  39-60        Dega
# DT0301118        1-4    Male    Illitrate     Rural  15-38        Dega
# DT1100717        1-4    Male     Teritary     Urban  15-38        Dega
# DT1200527        5-8    Male    Illitrate     Rural  61-84        Dega
# DT0300270        1-4    Male    Illitrate     Rural  61-84        Dega
#
#               Q401  Q304         Q306      Q307 Q308m Qsou_inform  \
# hhid
# DT0101175    Clean  Rent  Electricity  Charcoal   Yes   One_media
# DT0800529  Unclean  Rent       Battry      Muck    No   One_media
# DT0801695  Unclean  Rent       Battry      Muck    No       Never
# DT0101087    Clean  Rent  Electricity  Charcoal   Yes   Two_media
# DT0800565  Unclean  Rent       Battry      Muck    No   One_media
# ...            ...   ...          ...       ...   ...         ...
# DT1300742    Clean  Rent       Battry      Muck   Yes       Never
# DT0301118  Unclean  Rent       Battry      Muck    No       Never
# DT1100717    Clean  Rent       Battry  Charcoal   Yes   One_media
# DT1200527  Unclean  Rent   Wood/other      Muck    No       Never
# DT0300270  Unclean  Rent       Battry      Muck    No       Never
#
#                      Q504 Q5231 Q5232 Q5233 Q5234 Q524
# hhid
# DT0101175        Purchase   Yes    No    No    No   No
# DT0800529  Own_production    No    No    No    No  Yes
# DT0801695  Own_production    No    No    No    No  Yes
# DT0101087        Purchase    No    No    No    No   No
# DT0800565  Own_production    No    No    No    No   No
# ...                   ...   ...   ...   ...   ...  ...
# DT1300742        Purchase    No   Yes    No    No  Yes
# DT0301118  Own_production   Yes    No    No    No  Yes
# DT1100717        Purchase    No    No    No    No  Yes
# DT1200527        Purchase    No    No    No    No   No
# DT0300270  Own_production    No    No    No    No  Yes
#
# [10900 rows x 18 columns]

# %%
train=pd.concat([train,y_train],axis=1)
train
# Out:
#           hh_members     sex hh_education residence    age    altitude  \
# hhid
# DT0101175        1-4    Male   Elementary     Urban  61-84        Dega
# DT0800529        >=9    Male   Elementary     Rural  39-60  Woina_dega
# DT0801695        1-4    Male    Illitrate     Rural  15-38       Kolla
# DT0101087        1-4  Female    Illitrate     Urban  61-84        Dega
# DT0800565        1-4    Male    Secondary     Rural  15-38       Kolla
# ...              ...     ...          ...       ...    ...         ...
# DT1300742        1-4  Female    Illitrate     Rural  39-60        Dega
# DT0301118        1-4    Male    Illitrate     Rural  15-38        Dega
# DT1100717        1-4    Male     Teritary     Urban  15-38        Dega
# DT1200527        5-8    Male    Illitrate     Rural  61-84        Dega
# DT0300270        1-4    Male    Illitrate     Rural  61-84        Dega
#
#               Q401  Q304         Q306      Q307 Q308m Qsou_inform  \
# hhid
# DT0101175    Clean  Rent  Electricity  Charcoal   Yes   One_media
# DT0800529  Unclean  Rent       Battry      Muck    No   One_media
# DT0801695  Unclean  Rent       Battry      Muck    No       Never
# DT0101087    Clean  Rent  Electricity  Charcoal   Yes   Two_media
# DT0800565  Unclean  Rent       Battry      Muck    No   One_media
# ...            ...   ...          ...       ...   ...         ...
# DT1300742    Clean  Rent       Battry      Muck   Yes       Never
# DT0301118  Unclean  Rent       Battry      Muck    No       Never
# DT1100717    Clean  Rent       Battry  Charcoal   Yes   One_media
# DT1200527  Unclean  Rent   Wood/other      Muck    No       Never
# DT0300270  Unclean  Rent       Battry      Muck    No       Never
#
#                      Q504 Q5231 Q5232 Q5233 Q5234 Q524 Decision
# hhid
# DT0101175        Purchase   Yes    No    No    No   No       No
# DT0800529  Own_production    No    No    No    No  Yes      Yes
# DT0801695  Own_production    No    No    No    No  Yes       No
# DT0101087        Purchase    No    No    No    No   No      Yes
# DT0800565  Own_production    No    No    No    No   No      Yes
# ...                   ...   ...   ...   ...   ...  ...      ...
# DT1300742        Purchase    No   Yes    No    No  Yes       No
# DT0301118  Own_production   Yes    No    No    No  Yes       No
# DT1100717        Purchase    No    No    No    No  Yes      Yes
# DT1200527        Purchase    No    No    No    No   No       No
# DT0300270  Own_production    No    No    No    No  Yes      Yes
#
# [10900 rows x 19 columns]

# %%
#train=x_train[train]
test=pd.concat([test,y_test],axis=1)

# %%
#all relevant fetures for model developmnt 
test.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'Decision'],
#       dtype='object')

# %%
test
# Out:
#           hh_members     sex hh_education residence    age    altitude  \
# hhid
# DT1201929        5-8    Male    Illitrate     Rural  39-60  Woina_dega
# DT0601013        5-8    Male   Elementary     Urban  39-60        Dega
# DT1000301        1-4    Male    Illitrate     Rural  15-38        Dega
# DT0900088        1-4  Female   Elementary     Rural  39-60        Dega
# DT0700821        5-8    Male    Illitrate     Rural  39-60       Kolla
# ...              ...     ...          ...       ...    ...         ...
# DT1201583        1-4    Male   Elementary     Rural  39-60  Woina_dega
# DT1100535        1-4    Male    Secondary     Urban  15-38        Dega
# DT1201563        5-8  Female    Illitrate     Rural  39-60  Woina_dega
# DT1201095        5-8    Male    Illitrate     Rural  15-38        Dega
# DT1100908        1-4    Male     Teritary     Urban  15-38        Dega
#
#               Q401        Q304         Q306         Q307 Q308m Qsou_inform  \
# hhid
# DT1201929  Unclean        Rent  Electricity     Charcoal    No   One_media
# DT0601013  Unclean        Rent       Battry         Muck    No       Never
# DT1000301    Clean        Rent       Battry         Muck    No       Never
# DT0900088    Clean  Government  Electricity     Charcoal   Yes   One_media
# DT0700821  Unclean        Rent       Battry         Wood    No       Never
# ...            ...         ...          ...          ...   ...         ...
# DT1201583  Unclean        Rent  Electricity     Charcoal    No       Never
# DT1100535    Clean        Rent  Electricity     Charcoal    No   Two_media
# DT1201563  Unclean        Rent  Electricity     Charcoal    No   One_media
# DT1201095  Unclean        Rent       Battry         Muck    No       Never
# DT1100908    Clean     Private  Electricity  Electricity    No   One_media
#
#                      Q504 Q5231 Q5232 Q5233 Q5234 Q524 Decision
# hhid
# DT1201929        Purchase    No    No    No    No   No       No
# DT0601013  Own_production   Yes    No    No    No  Yes       No
# DT1000301  Own_production    No    No    No    No  Yes       No
# DT0900088        Purchase   Yes    No    No    No   No       No
# DT0700821  Own_production    No   Yes    No    No  Yes       No
# ...                   ...   ...   ...   ...   ...  ...      ...
# DT1201583        Purchase   Yes    No    No    No  Yes       No
# DT1100535  Own_production    No    No    No    No   No      Yes
# DT1201563        Purchase    No    No    No    No  Yes       No
# DT1201095        Purchase    No    No    No    No  Yes       No
# DT1100908        Purchase    No    No    No    No   No      Yes
#
# [2726 rows x 19 columns]

# %%
test.columns
# Out:
# Index(['hh_members', 'sex', 'hh_education', 'residence', 'age', 'altitude',
#        'Q401', 'Q304', 'Q306', 'Q307', 'Q308m', 'Qsou_inform', 'Q504', 'Q5231',
#        'Q5232', 'Q5233', 'Q5234', 'Q524', 'Decision'],
#       dtype='object')

# %%
test.shape
# Out:
# (2726, 19)

# %%
config = {'algorithm': 'C4.5'}
model = chef.fit(test, config)
# Out:
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# -------------------------
# finished in  367.71189284324646  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  93.91049156272928 % on  2726  instances
# Labels:  ['No' 'Yes']
# Confusion matrix:  [[1469, 52], [114, 1091]]
# Precision:  96.5812 %, Recall:  92.7985 %, F1:  94.6521 %

# %%
if __name__ == '__main__':
    config = {'algorithm': 'C4.5', 'enableParallelism': True}
    model = chef.fit(test, config)
    fi = chef.feature_importance()
    print(fi)
# Out:
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# -------------------------
# finished in  376.7318992614746  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  93.91049156272928 % on  2726  instances
# Labels:  ['No' 'Yes']
# Confusion matrix:  [[1473, 56], [110, 1087]]
# Precision:  96.3375 %, Recall:  93.0512 %, F1:  94.6658 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-7cd12577a33f> in <module>
#       2     config = {'algorithm': 'C4.5', 'enableParallelism': True}
#       3     model = chef.fit(test, config)
# ----> 4     fi = chef.feature_importance()
#       5     print(fi)
#
# TypeError: feature_importance() missing 1 required positional argument: 'rules'

# %%
test.iloc[2001]
# Out:
# hh_members                 1-4
# sex                       Male
# hh_education         Illitrate
# residence                Rural
# age                      39-60
# altitude            Woina_dega
# Q401                   Unclean
# Q304                      Rent
# Q306                    Battry
# Q307                      Muck
# Q308m                       No
# Qsou_inform              Never
# Q504            Own_production
# Q5231                       No
# Q5232                       No
# Q5233                       No
# Q5234                       No
# Q524                       Yes
# Decision                   Yes
# Name: DT0800034, dtype: object

# %%
test
# Out:
#           hh_members     sex hh_education residence    age    altitude  \
# hhid
# DT1201929        5-8    Male    Illitrate     Rural  39-60  Woina_dega
# DT0601013        5-8    Male   Elementary     Urban  39-60        Dega
# DT1000301        1-4    Male    Illitrate     Rural  15-38        Dega
# DT0900088        1-4  Female   Elementary     Rural  39-60        Dega
# DT0700821        5-8    Male    Illitrate     Rural  39-60       Kolla
# ...              ...     ...          ...       ...    ...         ...
# DT1201583        1-4    Male   Elementary     Rural  39-60  Woina_dega
# DT1100535        1-4    Male    Secondary     Urban  15-38        Dega
# DT1201563        5-8  Female    Illitrate     Rural  39-60  Woina_dega
# DT1201095        5-8    Male    Illitrate     Rural  15-38        Dega
# DT1100908        1-4    Male     Teritary     Urban  15-38        Dega
#
#               Q401        Q304         Q306         Q307 Q308m Qsou_inform  \
# hhid
# DT1201929  Unclean        Rent  Electricity     Charcoal    No   One_media
# DT0601013  Unclean        Rent       Battry         Muck    No       Never
# DT1000301    Clean        Rent       Battry         Muck    No       Never
# DT0900088    Clean  Government  Electricity     Charcoal   Yes   One_media
# DT0700821  Unclean        Rent       Battry         Wood    No       Never
# ...            ...         ...          ...          ...   ...         ...
# DT1201583  Unclean        Rent  Electricity     Charcoal    No       Never
# DT1100535    Clean        Rent  Electricity     Charcoal    No   Two_media
# DT1201563  Unclean        Rent  Electricity     Charcoal    No   One_media
# DT1201095  Unclean        Rent       Battry         Muck    No       Never
# DT1100908    Clean     Private  Electricity  Electricity    No   One_media
#
#                      Q504 Q5231 Q5232 Q5233 Q5234 Q524 Decision
# hhid
# DT1201929        Purchase    No    No    No    No   No       No
# DT0601013  Own_production   Yes    No    No    No  Yes       No
# DT1000301  Own_production    No    No    No    No  Yes       No
# DT0900088        Purchase   Yes    No    No    No   No       No
# DT0700821  Own_production    No   Yes    No    No  Yes       No
# ...                   ...   ...   ...   ...   ...  ...      ...
# DT1201583        Purchase   Yes    No    No    No  Yes       No
# DT1100535  Own_production    No    No    No    No   No      Yes
# DT1201563        Purchase    No    No    No    No  Yes       No
# DT1201095        Purchase    No    No    No    No  Yes       No
# DT1100908        Purchase    No    No    No    No   No      Yes
#
# [2726 rows x 19 columns]

# %%
test.iloc[222]
# Out:
# hh_members             5-8
# sex                   Male
# hh_education    Elementary
# residence            Urban
# age                  39-60
# altitude              Dega
# Q401                 Clean
# Q304                  Rent
# Q306                Battry
# Q307                  Muck
# Q308m                   No
# Qsou_inform      One_media
# Q504              Purchase
# Q5231                   No
# Q5232                   No
# Q5233                   No
# Q5234                   No
# Q524                   Yes
# Decision               Yes
# Name: DT0600351, dtype: object

# %%
predction=chef.predict(model,test.iloc[222])
predction
# Out:
# 'Yes'

# %%
for index,instance in test.iterrows():
    prediction=chef.predict(model,instance)
    actual=instance['Decision']
    if actual==prediction:
        classified=True
    else:
        classified=False
        print("*",end='')
   
    print(actual,"-",prediction)
# Out:
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *Yes - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *Yes - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# *Yes - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# *No - Yes
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *Yes - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# *Yes - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# *Yes - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# *Yes - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# *Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *Yes - No
# Yes - Yes
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# *Yes - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# *Yes - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# *No - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# *Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *Yes - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *Yes - No
# *No - Yes
# No - No
# No - No
# *Yes - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# *Yes - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *Yes - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# *No - Yes
# Yes - Yes
# No - No
# No - No
# *Yes - No
# *Yes - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# *No - Yes
# No - No
# No - No
# No - No
# *Yes - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# *Yes - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# *Yes - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# *No - Yes
# *Yes - No
# No - No
# Yes - Yes
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# *No - Yes
# No - No
# *No - Yes
# No - No
# *No - Yes
# No - No
# *No - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# *Yes - No
# No - No
# Yes - Yes
# *Yes - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# No - No
# *Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# Yes - Yes
# *Yes - No
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# *Yes - No
# *No - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# *No - Yes
# No - No
# No - No
# No - No
# No - No
# No - No
# No - No
# *Yes - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# *No - Yes
# *No - Yes
# No - No
# No - No
# No - No
# *Yes - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# Yes - Yes
# *Yes - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# No - No
# Yes - Yes
# Yes - Yes
# No - No
# No - No
# *No - Yes
# No - No
# No - No
# Yes - Yes
# No - No
# Yes - Yes
# *No - Yes
# No - No
# Yes - Yes
